# %% [markdown]
# # Microsoft Foundry Local
# ## Discovering Foundry Local models
#
# This notebook demonstrates how to use **Microsoft Foundry Local** to run AI models locally on your machine using the ONNX Runtime.
#
# <img src="https://github.com/retkowsky/images/blob/master/foundrylocal.jpg?raw=true">
#
# **What this notebook covers:**
# 1. **Service Setup** — Initialize the Foundry Local service and inspect connection details
# 2. **Model Catalog** — Browse, filter, and visualize all available models
# 3. **Cache Management** — Inspect locally downloaded models
# 4. **Inference** — Load models and run chat completions via the OpenAI SDK
# 5. **Cleanup** — Unload models to free memory
#
# **Prerequisites:**
# - Foundry Local CLI installed and on your `PATH` (`foundry --version`)
# - Python 3.10+ (tested on 3.12)
# - Packages: `foundry-local-sdk`, `openai`, `pandas`, `matplotlib`
#
# > **Docs:** [Foundry Local Documentation](https://learn.microsoft.com/azure/ai-foundry/foundry-local/)
# > **SDK Reference:** [Python SDK Reference](https://learn.microsoft.com/azure/ai-foundry/foundry-local/reference/reference-sdk?pivots=programming-language-python)

# %% [markdown]
# ## 🚀 Why Microsoft Foundry Local?
#
# Foundry Local brings the convenience of cloud AI APIs to your local machine, combining **privacy**, **cost savings**, and **developer-friendly tooling** in a single package.
#
# ---
#
# ### 🔒 Privacy & Data Sovereignty
#
# Your data never leaves your machine. All inference runs locally, making it ideal for **regulated industries** (healthcare, finance, legal) where data residency and compliance matter.
#
# ---
#
# ### 💰 Zero Cost at Runtime
#
# No API calls, no per-token billing, no subscription fees. Once the model is cached locally, inference is **entirely free** — perfect for prototyping, experimentation, or high-volume workloads.
#
# ---
#
# ### ⚡ Offline Capability & Low Latency
#
# No network dependency means consistent performance regardless of connectivity. Responses are fast since everything runs on your hardware with **no round-trip to the cloud**.
#
# ---
#
# ### 🛠️ Seamless Developer Experience
#
# Foundry Local exposes an **OpenAI-compatible API**, so you can reuse existing code, libraries, and frameworks (`LangChain`, `OpenAI SDK`, etc.) with minimal changes — just swap the endpoint.
#
# ---
#
# ### 💻 Optimized for Consumer Hardware
#
# Models are compiled and optimized via **Microsoft Olive** for efficient execution on CPUs and integrated GPUs (via `ONNX Runtime` + `DirectML` on Windows), so you don't need a dedicated high-end GPU.
#
# ---
#
# ### 📦 Curated Model Catalog
#
# Access to a growing catalog of pre-optimized models (`Phi-4`, `Phi-3.5`, `Qwen`, `Mistral`, `DeepSeek`…) that are ready to run out of the box, with support for **custom compiled models** as well.
#
# ---
#
# ### 🔧 Built-in Tool / Function Calling
#
# Native support for **structured function calling**, enabling agentic workflows and tool-augmented applications locally.
#
# ---
#
# ### ☁️ Smooth Cloud Migration Path
#
# Since Foundry Local aligns with the broader **Azure AI Foundry** ecosystem, you can prototype locally and scale to Azure cloud services when needed, with minimal code changes.
#
# ---
#
# > **In short** — Foundry Local lets you run powerful AI models on your own hardware with full privacy, zero runtime costs, and a developer experience that mirrors the cloud. No GPU required. No internet needed. Just download, run, and build.

# %%
#%pip install foundry-local-sdk openai pandas matplotlib --quiet

# %%
import datetime
import GPUtil
import matplotlib.pyplot as plt
import os
import pandas as pd
import platform
import psutil
import sys

from openai import OpenAI
from foundry_local import FoundryLocalManager

# %%
print(f"Python version: {sys.version}")
# Out:
# Python version: 3.12.12 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 20:05:38) [MSC v.1929 64 bit (AMD64)]

# %%
print(f"Today is {datetime.datetime.today().strftime('%d-%b-%Y %H:%M:%S')}")
# Out:
# Today is 24-Feb-2026 14:27:30

# %%
print(f"💻 OS: {platform.system()} {platform.release()}")
print(f"- CPU: {platform.processor()}")
print(f"- CPU cores: {psutil.cpu_count(logical=False)} physical, {psutil.cpu_count()} logical")

ram = psutil.virtual_memory()
print(f"- RAM total:     {ram.total / (1024**3):.1f} GB")
print(f"- RAM available: {ram.available / (1024**3):.1f} GB")
print(f"- RAM used:      {ram.percent}%")

for part in psutil.disk_partitions():
    try:
        usage = psutil.disk_usage(part.mountpoint)
        print(f"\n💾 Disk [{part.device}] mounted on {part.mountpoint}")
        print(f"- Total: {usage.total / (1024**3):.1f} GB")
        print(f"- Used:  {usage.used / (1024**3):.1f} GB ({usage.percent}%)")
        print(f"- Free:  {usage.free / (1024**3):.1f} GB")
    except PermissionError:
        pass

gpus = GPUtil.getGPUs()

if not gpus:
    print("No GPU detected.")
else:
    for i, gpu in enumerate(gpus):
        print(f"\n🎮 GPU {i} — {gpu.name}")
        print(f"- VRAM Total : {gpu.memoryTotal:,.0f} MB")
        print(f"- VRAM Used  : {gpu.memoryUsed:,.0f} MB ({gpu.memoryUtil * 100:.0f}%)")
        print(f"- VRAM Free  : {gpu.memoryFree:,.0f} MB")
        print(f"- GPU Load   : {gpu.load * 100:.0f}%")
        print(f"- Temperature: {gpu.temperature} °C")
# Out:
# 💻 OS: Windows 11
# - CPU: Intel64 Family 6 Model 141 Stepping 1, GenuineIntel
# - CPU cores: 8 physical, 16 logical
# - RAM total:     63.7 GB
# - RAM available: 31.4 GB
# - RAM used:      50.6%
#
# 💾 Disk [C:\] mounted on C:\
# - Total: 951.6 GB
# - Used:  883.9 GB (92.9%)
# - Free:  67.8 GB
#
# 🎮 GPU 0 — NVIDIA T1200 Laptop GPU
# - VRAM Total : 4,096 MB
# - VRAM Used  : 3,813 MB (93%)
# - VRAM Free  : 123 MB
# - GPU Load   : 13%
# - Temperature: 65.0 °C

# %% [markdown]
# ## Helper Functions
#
# Utility functions used throughout the notebook to convert model lists into DataFrames and plot distributions.

# %%
def models_to_df(models):
    """Convert a list of FoundryModelInfo objects into a clean DataFrame."""
    return pd.DataFrame([
        {
            "alias": m.alias,
            "id": m.id,
            "device": m.device_type.value,
            "provider": m.execution_provider,
            "size_mb": m.file_size_mb,
            "tools": m.supports_tool_calling,
            "license": m.license,
            "task": m.task,
        }
        for m in models
    ])


def plot_value_counts(df, column, title="Value Counts", xlabel="Count",
                      figsize=(10, 5), color="steelblue"):
    """Horizontal bar chart of value counts for a given column."""
    fig, ax = plt.subplots(figsize=figsize)
    data = df[column].value_counts(sort=True)
    data.plot.barh(ax=ax, color=color, edgecolor="white")
    for i, (value, name) in enumerate(zip(data.values, data.index)):
        ax.text(value + 0.1, i, str(value), va="center", fontsize=10)
    ax.set_xlabel(xlabel, fontsize=12)
    ax.set_ylabel("")
    ax.set_title(title, fontsize=14)
    ax.invert_yaxis()
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Service Setup
#
# Initialize the `FoundryLocalManager` which starts the local inference service if not already running.
# The service exposes an **OpenAI-compatible REST endpoint** on a dynamically allocated port.

# %%
manager = FoundryLocalManager()
manager.start_service()

print(f"Service running : {manager.is_service_running()}")
print(f"Service URI     : {manager.service_uri}")
print(f"Endpoint (v1)   : {manager.endpoint}")
print(f"Cache location  : {manager.get_cache_location()}")
# Out:
# Service running : True
# Service URI     : http://127.0.0.1:51466
# Endpoint (v1)   : http://127.0.0.1:51466/v1
# Cache location  : C:\models

# %%
# List all public methods and properties
print([m for m in dir(manager) if not m.startswith("_")])
# Out:
# ['api_key', 'download_model', 'endpoint', 'get_cache_location', 'get_model_info', 'httpx_client', 'is_model_upgradeable', 'is_service_running', 'list_cached_models', 'list_catalog_models', 'list_loaded_models', 'load_model', 'refresh_catalog', 'service_uri', 'start_service', 'unload_model', 'upgrade_model']

# %% [markdown]
# ## Model Catalog
#
# The catalog lists all models published in the Foundry registry.
# Each alias (e.g. `phi-4`) maps to multiple **variants** optimized for different hardware (CPU, CUDA GPU, OpenVINO GPU, etc.).

# %%
catalog = manager.list_catalog_models()
print(f"Total model variants in catalog = {len(catalog)}")

df_catalog = models_to_df(catalog)
df_catalog.head(10)
# Out:
# Total model variants in catalog = 80
#              alias                                       id device  \
# 0            phi-4                         Phi-4-cuda-gpu:1    GPU
# 1            phi-4                     phi-4-openvino-gpu:1    GPU
# 2            phi-4                      Phi-4-generic-gpu:1    GPU
# 3            phi-4                      Phi-4-generic-cpu:1    CPU
# 4     phi-3.5-mini         Phi-3.5-mini-instruct-cuda-gpu:1    GPU
# 5     phi-3.5-mini     Phi-3.5-mini-instruct-openvino-gpu:1    GPU
# 6     phi-3.5-mini      Phi-3.5-mini-instruct-generic-gpu:1    GPU
# 7     phi-3.5-mini      Phi-3.5-mini-instruct-generic-cpu:1    CPU
# 8  phi-3-mini-128k      Phi-3-mini-128k-instruct-cuda-gpu:1    GPU
# 9  phi-3-mini-128k  Phi-3-mini-128k-instruct-openvino-gpu:1    GPU
#
#                     provider  size_mb  tools license             task
# 0      CUDAExecutionProvider     8570  False     MIT  chat-completion
# 1  OpenVINOExecutionProvider     9046  False     MIT  chat-completion
# 2    WebGpuExecutionProvider     8570  False     MIT  chat-completion
# 3       CPUExecutionProvider    10403  False     MIT  chat-completion
# 4      CUDAExecutionProvider     2181  False     MIT  chat-completion
# 5  OpenVINOExecutionProvider     1993  False     MIT  chat-completion
# 6    WebGpuExecutionProvider     2211  False     MIT  chat-completion
# 7       CPUExecutionProvider     2590  False     MIT  chat-completion
# 8      CUDAExecutionProvider     2181  False     MIT  chat-completion
# 9  OpenVINOExecutionProvider     2328  False     MIT  chat-completion

# %%
# Saving all models to Excel
df_catalog.to_excel("models.xlsx", index=False)

# %% [markdown]
# ### Filtering the Catalog
#
# You can filter by alias, device type, task, or any column.

# %%
# Filter by alias keyword
df_catalog[df_catalog["alias"].str.contains("phi-4", case=False, na=False)]
# Out:
#                    alias                                   id device  \
# 0                  phi-4                     Phi-4-cuda-gpu:1    GPU
# 1                  phi-4                 phi-4-openvino-gpu:1    GPU
# 2                  phi-4                  Phi-4-generic-gpu:1    GPU
# 3                  phi-4                  Phi-4-generic-cpu:1    CPU
# 40  phi-4-mini-reasoning      Phi-4-mini-reasoning-cuda-gpu:3    GPU
# 41  phi-4-mini-reasoning  Phi-4-mini-reasoning-openvino-gpu:2    GPU
# 42  phi-4-mini-reasoning   Phi-4-mini-reasoning-generic-gpu:3    GPU
# 43  phi-4-mini-reasoning   Phi-4-mini-reasoning-generic-cpu:3    CPU
# 56            phi-4-mini       Phi-4-mini-instruct-cuda-gpu:5    GPU
# 57            phi-4-mini   phi-4-mini-instruct-openvino-gpu:2    GPU
# 58            phi-4-mini    Phi-4-mini-instruct-generic-gpu:5    GPU
# 59            phi-4-mini    Phi-4-mini-instruct-generic-cpu:5    CPU
#
#                      provider  size_mb  tools license             task
# 0       CUDAExecutionProvider     8570  False     MIT  chat-completion
# 1   OpenVINOExecutionProvider     9046  False     MIT  chat-completion
# 2     WebGpuExecutionProvider     8570  False     MIT  chat-completion
# 3        CPUExecutionProvider    10403  False     MIT  chat-completion
# 40      CUDAExecutionProvider     3225  False     MIT  chat-completion
# 41  OpenVINOExecutionProvider     2532  False     MIT  chat-completion
# 42    WebGpuExecutionProvider     3225  False     MIT  chat-completion
# 43       CPUExecutionProvider     4628  False     MIT  chat-completion
# 56      CUDAExecutionProvider     3686   True     MIT  chat-completion
# 57  OpenVINOExecutionProvider     2205   True     MIT  chat-completion
# 58    WebGpuExecutionProvider     3809   True     MIT  chat-completion
# 59       CPUExecutionProvider     4915   True     MIT  chat-completion

# %%
# CPU-only models
df_catalog[df_catalog["device"] == "CPU"]
# Out:
#                      alias                                                id  \
# 3                    phi-4                               Phi-4-generic-cpu:1
# 7             phi-3.5-mini               Phi-3.5-mini-instruct-generic-cpu:1
# 11         phi-3-mini-128k            Phi-3-mini-128k-instruct-generic-cpu:2
# 15           phi-3-mini-4k              Phi-3-mini-4k-instruct-generic-cpu:2
# 19         mistral-7b-v0.2  mistralai-Mistral-7B-Instruct-v0-2-generic-cpu:2
# 23         deepseek-r1-14b        deepseek-r1-distill-qwen-14b-generic-cpu:3
# 27          deepseek-r1-7b         deepseek-r1-distill-qwen-7b-generic-cpu:3
# 29            whisper-base                 openai-whisper-base-generic-cpu:1
# 31          whisper-medium               openai-whisper-medium-generic-cpu:1
# 33           whisper-small                openai-whisper-small-generic-cpu:1
# 35            whisper-tiny                 openai-whisper-tiny-generic-cpu:2
# 39      qwen2.5-coder-0.5b         qwen2.5-coder-0.5b-instruct-generic-cpu:4
# 43    phi-4-mini-reasoning                Phi-4-mini-reasoning-generic-cpu:3
# 47            qwen2.5-0.5b               qwen2.5-0.5b-instruct-generic-cpu:4
# 51            qwen2.5-1.5b               qwen2.5-1.5b-instruct-generic-cpu:4
# 55      qwen2.5-coder-1.5b         qwen2.5-coder-1.5b-instruct-generic-cpu:4
# 59              phi-4-mini                 Phi-4-mini-instruct-generic-cpu:5
# 63             qwen2.5-14b                qwen2.5-14b-instruct-generic-cpu:4
# 67       qwen2.5-coder-14b          qwen2.5-coder-14b-instruct-generic-cpu:4
# 71        qwen2.5-coder-7b           qwen2.5-coder-7b-instruct-generic-cpu:4
# 75              qwen2.5-7b                 qwen2.5-7b-instruct-generic-cpu:4
# 77  whisper-large-v3-turbo       openai-whisper-large-v3-turbo-generic-cpu:2
# 78             gpt-oss-20b                         gpt-oss-20b-generic-cpu:1
#
#    device              provider  size_mb  tools     license  \
# 3     CPU  CPUExecutionProvider    10403  False         MIT
# 7     CPU  CPUExecutionProvider     2590  False         MIT
# 11    CPU  CPUExecutionProvider     2600  False         MIT
# 15    CPU  CPUExecutionProvider     2590  False         MIT
# 19    CPU  CPUExecutionProvider     4167  False  apache-2.0
# 23    CPU  CPUExecutionProvider    11786  False         MIT
# 27    CPU  CPUExecutionProvider     6584  False         MIT
# 29    CPU  CPUExecutionProvider      383  False  apache-2.0
# 31    CPU  CPUExecutionProvider     3122  False  apache-2.0
# 33    CPU  CPUExecutionProvider     1079  False  apache-2.0
# 35    CPU  CPUExecutionProvider      225  False  apache-2.0
# 39    CPU  CPUExecutionProvider      822   True  apache-2.0
# 43    CPU  CPUExecutionProvider     4628  False         MIT
# 47    CPU  CPUExecutionProvider      822   True  apache-2.0
# 51    CPU  CPUExecutionProvider     1822   True  apache-2.0
# 55    CPU  CPUExecutionProvider     1822   True  apache-2.0
# 59    CPU  CPUExecutionProvider     4915   True         MIT
# 63    CPU  CPUExecutionProvider    11325   True  apache-2.0
# 67    CPU  CPUExecutionProvider    11325   True  apache-2.0
# 71    CPU  CPUExecutionProvider     6307   True  apache-2.0
# 75    CPU  CPUExecutionProvider     6307   True  apache-2.0
# 77    CPU  CPUExecutionProvider     9000  False  apache-2.0
# 78    CPU  CPUExecutionProvider    12552  False         MIT
#
#                             task
# 3                chat-completion
# 7                chat-completion
# 11               chat-completion
# 15               chat-completion
# 19               chat-completion
# 23               chat-completion
# 27               chat-completion
# 29  automatic-speech-recognition
# 31  automatic-speech-recognition
# 33  automatic-speech-recognition
# 35  automatic-speech-recognition
# 39               chat-completion
# 43               chat-completion
# 47               chat-completion
# 51               chat-completion
# 55               chat-completion
# 59               chat-completion
# 63               chat-completion
# 67               chat-completion
# 71               chat-completion
# 75               chat-completion
# 77  automatic-speech-recognition
# 78               chat-completion

# %%
# Speech-to-text models (Whisper family)
df_catalog[df_catalog["task"] == "automatic-speech-recognition"]
# Out:
#                      alias                                           id  \
# 28            whisper-base               openai-whisper-base-cuda-gpu:1
# 29            whisper-base            openai-whisper-base-generic-cpu:1
# 30          whisper-medium             openai-whisper-medium-cuda-gpu:1
# 31          whisper-medium          openai-whisper-medium-generic-cpu:1
# 32           whisper-small              openai-whisper-small-cuda-gpu:1
# 33           whisper-small           openai-whisper-small-generic-cpu:1
# 34            whisper-tiny               openai-whisper-tiny-cuda-gpu:1
# 35            whisper-tiny            openai-whisper-tiny-generic-cpu:2
# 76  whisper-large-v3-turbo     openai-whisper-large-v3-turbo-cuda-gpu:2
# 77  whisper-large-v3-turbo  openai-whisper-large-v3-turbo-generic-cpu:2
#
#    device               provider  size_mb  tools     license  \
# 28    GPU  CUDAExecutionProvider      194  False  apache-2.0
# 29    CPU   CPUExecutionProvider      383  False  apache-2.0
# 30    GPU  CUDAExecutionProvider     1564  False  apache-2.0
# 31    CPU   CPUExecutionProvider     3122  False  apache-2.0
# 32    GPU  CUDAExecutionProvider      542  False  apache-2.0
# 33    CPU   CPUExecutionProvider     1079  False  apache-2.0
# 34    GPU  CUDAExecutionProvider      115  False  apache-2.0
# 35    CPU   CPUExecutionProvider      225  False  apache-2.0
# 76    GPU  CUDAExecutionProvider     9000  False  apache-2.0
# 77    CPU   CPUExecutionProvider     9000  False  apache-2.0
#
#                             task
# 28  automatic-speech-recognition
# 29  automatic-speech-recognition
# 30  automatic-speech-recognition
# 31  automatic-speech-recognition
# 32  automatic-speech-recognition
# 33  automatic-speech-recognition
# 34  automatic-speech-recognition
# 35  automatic-speech-recognition
# 76  automatic-speech-recognition
# 77  automatic-speech-recognition

# %% [markdown]
# ### Catalog Visualizations

# %%
plot_value_counts(df_catalog, "alias",
                  title="Available Models by Alias",
                  xlabel="Number of Variants",
                  figsize=(10, 8), color="blue")

# %%
plot_value_counts(df_catalog, "device",
                  title="Models by Device Type",
                  xlabel="Count", color="coral")

# %%
plot_value_counts(df_catalog, "provider",
                  title="Models by Execution Provider",
                  xlabel="Count", color="orange")

# %%
plot_value_counts(df_catalog, "task",
                  title="Models by Task",
                  xlabel="Count", color="mediumpurple")

# %% [markdown]
# ## Cache Management
#
# Downloaded models are stored in the local cache. This avoids re-downloading models each time you load them.

# %%
cached = manager.list_cached_models()
print(f"Cached models = {len(cached)}")

df_cached = models_to_df(cached)
df_cached
# Out:
# Cached models = 3
#         alias                              id device               provider  \
# 0       phi-4                Phi-4-cuda-gpu:1    GPU  CUDAExecutionProvider
# 1       phi-4             Phi-4-generic-cpu:1    CPU   CPUExecutionProvider
# 2  phi-4-mini  Phi-4-mini-instruct-cuda-gpu:5    GPU  CUDAExecutionProvider
#
#    size_mb  tools license             task
# 0     8570  False     MIT  chat-completion
# 1    10403  False     MIT  chat-completion
# 2     3686   True     MIT  chat-completion

# %% [markdown]
# ## Inference with OpenAI SDK
#
# Foundry Local exposes an **OpenAI-compatible** endpoint, so you can use the standard `openai` Python package.
#
# **Workflow:**
# 1. Load a model into the inference engine with `manager.load_model()`
# 2. Create an `OpenAI` client pointing to the local endpoint
# 3. Call `client.chat.completions.create()` using the model **ID string**
#
# **Tip:** Always pass `model_info.id` (a string) to the OpenAI client, not the model object itself.

# %% [markdown]
# ### Using phi-4

# %% [markdown]
# > https://huggingface.co/microsoft/phi-4

# %%
manager.download_model("Phi-4-generic-cpu:1")
# Out:
# FoundryModelInfo(alias=phi-4, id=Phi-4-generic-cpu:1, execution_provider=CPUExecutionProvider, device_type=CPU, file_size=10403 MB, license=MIT)

# %%
# Load a model into memory
model_info = manager.load_model("Phi-4-generic-cpu:1")
print(f"Loaded: {model_info.alias} => {model_info.id}")
# Out:
# Loaded: phi-4 => Phi-4-generic-cpu:1

# %%
# Initialize the OpenAI client
client = OpenAI(
    base_url=manager.endpoint,
    api_key=manager.api_key
)

# %%
# Run a simple chat completion
response = client.chat.completions.create(
    model=model_info.id,
    messages=[{"role": "user", "content": "Hello, who are you?"}]
)

print(response.choices[0].message.content)
# Out:
# Hello! I'm Phi, a language model developed by Microsoft. I'm here to assist you with a wide range of questions and topics. Whether you need help with information, explanations, or guidance on various subjects, feel free to ask!

# %%
# Inspect the full response object
print(f"Model used : {response.model}")
print(f"Finish     : {response.choices[0].finish_reason}")
# Out:
# Model used : Phi-4-generic-cpu:1
# Finish     : stop

# %% [markdown]
# ### Using gpt-oss-20b
#
# You can load multiple models simultaneously (memory permitting) and switch between them.

# %% [markdown]
# > https://huggingface.co/openai/gpt-oss-20b

# %%
# Filter by alias keyword
df_catalog[df_catalog["alias"].str.contains("gpt-oss-20b", case=False, na=False)]
# Out:
#           alias                         id device               provider  \
# 78  gpt-oss-20b  gpt-oss-20b-generic-cpu:1    CPU   CPUExecutionProvider
# 79  gpt-oss-20b     gpt-oss-20b-cuda-gpu:1    GPU  CUDAExecutionProvider
#
#     size_mb  tools     license             task
# 78    12552  False         MIT  chat-completion
# 79     9882  False  apache-2.0  chat-completion

# %%
manager.download_model("gpt-oss-20b-generic-cpu:1")
# Out:
# FoundryModelInfo(alias=gpt-oss-20b, id=gpt-oss-20b-generic-cpu:1, execution_provider=CPUExecutionProvider, device_type=CPU, file_size=12552 MB, license=MIT)

# %%
# Load a second model
model_info_2 = manager.load_model("gpt-oss-20b-generic-cpu:1")
print(f"Loaded: {model_info_2.alias} => {model_info_2.id}")
# Out:
# Loaded: gpt-oss-20b => gpt-oss-20b-generic-cpu:1

# %%
response_2 = client.chat.completions.create(
    model=model_info_2.id,
    messages=[{"role": "user", "content": "Hello, who are you?"}]
)

print(f"Model: {response_2.model}")
print(response_2.choices[0].message.content)
# Out:
# Model: gpt-oss-20b-generic-cpu:1
# <|channel|>analysis<|message|>We need to respond politely, introduction, etc.<|end|><|start|>assistant<|channel|>final<|message|>I’m ChatGPT, a large‑language‑model created by OpenAI. I can help you with questions, explanations, or just a friendly chat. How can I assist you today?

# %% [markdown]
# ## Loaded Models
#
# Check which models are currently loaded in the inference engine.

# %%
loaded = manager.list_loaded_models()

# %%
print(loaded)
# Out:
# [FoundryModelInfo(alias=phi-4, id=Phi-4-generic-cpu:1, execution_provider=CPUExecutionProvider, device_type=CPU, file_size=10403 MB, license=MIT), FoundryModelInfo(alias=gpt-oss-20b, id=gpt-oss-20b-generic-cpu:1, execution_provider=CPUExecutionProvider, device_type=CPU, file_size=12552 MB, license=MIT)]

# %%
df_loaded = pd.DataFrame([
    {
        "alias": m.alias,
        "id": m.id,
        "device": m.device_type.value,
        "size_mb": m.file_size_mb,
        "tools_support": m.supports_tool_calling,
    }
    for m in loaded
])

display(df_loaded)
# Out:
#          alias                         id device  size_mb  tools_support
# 0        phi-4        Phi-4-generic-cpu:1    CPU    10403          False
# 1  gpt-oss-20b  gpt-oss-20b-generic-cpu:1    CPU    12552          False

# %% [markdown]
# ## Cleanup
#
# Unload models to free up memory when you're done.
# This does **not** delete them from the cache — they can be reloaded instantly.

# %%
# Unload all currently loaded models
for m in manager.list_loaded_models():
    manager.unload_model(m.id)

# %% [markdown]
# > Go to next notebook
